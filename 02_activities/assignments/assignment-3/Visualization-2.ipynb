# %% [markdown]
# Assignment 3 - Part 2
# Python Visualization Script

# %%
# Import Libraries 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests
